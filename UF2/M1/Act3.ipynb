# %% [markdown]
# # Actividad 3

# %%
import pandas as pd
import numpy

Presidentes = pd.read_csv("./us_presidents.csv")
Presidentes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45 entries, 0 to 44
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  45 non-null     int64
#  1   S.No.       45 non-null     int64
#  2   start       45 non-null     object
#  3   end         44 non-null     object
#  4   president   45 non-null     object
#  5   prior       45 non-null     object
#  6   party       45 non-null     object
#  7   vice        45 non-null     object
# dtypes: int64(2), object(6)
# memory usage: 2.9+ KB

# %%
Presidentes.president.str.startswith("J")
# Out:
# 0     False
# 1      True
# 2     False
# 3      True
# 4      True
# 5      True
# 6     False
# 7     False
# 8     False
# 9      True
# 10     True
# 11    False
# 12    False
# 13    False
# 14     True
# 15    False
# 16    False
# 17    False
# 18    False
# 19     True
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34     True
# 35    False
# 36    False
# 37    False
# 38     True
# 39    False
# 40    False
# 41    False
# 42    False
# 43    False
# 44    False
# Name: president, dtype: bool

# %%
Presidentes.president.str.split()
# Out:
# 0           [George, Washington]
# 1                  [John, Adams]
# 2            [Thomas, Jefferson]
# 3               [James, Madison]
# 4                [James, Monroe]
# 5          [John, Quincy, Adams]
# 6              [Andrew, Jackson]
# 7           [Martin, Van, Buren]
# 8     [William, Henry, Harrison]
# 9                  [John, Tyler]
# 10             [James, K., Polk]
# 11             [Zachary, Taylor]
# 12           [Millard, Fillmore]
# 13            [Franklin, Pierce]
# 14             [James, Buchanan]
# 15            [Abraham, Lincoln]
# 16             [Andrew, Johnson]
# 17          [Ulysses, S., Grant]
# 18       [Rutherford, B., Hayes]
# 19         [James, A., Garfield]
# 20         [Chester, A., Arthur]
# 21           [Grover, Cleveland]
# 22          [Benjamin, Harrison]
# 23           [Grover, Cleveland]
# 24           [William, McKinley]
# 25         [Theodore, Roosevelt]
# 26       [William, Howard, Taft]
# 27             [Woodrow, Wilson]
# ...

# %%
Presidentes["president_upper"] = Presidentes.president.str.upper()
Presidentes.sample(3)
# Out:
#     Unnamed: 0  S.No.           start            end          president  \
# 0            0      1  April 30, 1789  March 4, 1797  George Washington
# 11          11     12   March 4, 1849   July 9, 1850     Zachary Taylor
# 29          29     30  August 2, 1923  March 4, 1929    Calvin Coolidge
#
#                                                 prior               party  \
# 0   Commander-in-Chief  of the  Continental Army  ...  Nonpartisan   [13]
# 11  Major General  of the  1st Infantry Regiment  ...                Whig
# 29          29th  Vice President of the United States          Republican
#
#                 vice    president_upper
# 0         John Adams  GEORGE WASHINGTON
# 11  Millard Fillmore     ZACHARY TAYLOR
# 29     Office vacant    CALVIN COOLIDGE

# %%
Presidentes["length"] = Presidentes.president.str.len()
Presidentes.sample(3)
# Out:
#     Unnamed: 0  S.No.          start             end          president  \
# 28          28     29  March 4, 1921  August 2, 1923  Warren G. Harding
# 6            6      7  March 4, 1829   March 4, 1837     Andrew Jackson
# 9            9     10  April 4, 1841   March 4, 1845         John Tyler
#
#                                                 prior  \
# 28  U.S. Senator   ( Class 3 )   from  Ohio   (191...
# 6   U.S. Senator   ( Class 2 )   from  Tennessee  ...
# 9           10th  Vice President of the United States
#
#                                           party             vice  \
# 28                                   Republican  Calvin Coolidge
# 6                                    Democratic  John C. Calhoun
# 9   Whig   April 4, 1841  –  September 13, 1841    Office vacant
#
#       president_upper  length
# 28  WARREN G. HARDING      17
# 6      ANDREW JACKSON      14
# 9          JOHN TYLER      10

# %%
Presidentes.president.str.len() < 12
# Out:
# 0     False
# 1      True
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9      True
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# 37     True
# 38    False
# 39    False
# 40    False
# 41    False
# 42    False
# 43    False
# 44    False
# Name: president, dtype: bool

# %%
long_menor12 = Presidentes.president.str.len() < 12
Presidentes[long_menor12]
# Out:
#     Unnamed: 0  S.No.           start               end    president  \
# 1            1      2   March 4, 1797     March 4, 1801   John Adams
# 9            9     10   April 4, 1841     March 4, 1845   John Tyler
# 37          37     38  August 9, 1974  January 20, 1977  Gerald Ford
#
#                                         prior  \
# 1    1st  Vice President of the United States
# 9   10th  Vice President of the United States
# 37  40th  Vice President of the United States
#
#                                           party              vice  \
# 1                                    Federalist  Thomas Jefferson
# 9   Whig   April 4, 1841  –  September 13, 1841     Office vacant
# 37                                   Republican     Office vacant
#
#    president_upper  length
# 1       JOHN ADAMS      10
# 9       JOHN TYLER      10
# 37     GERALD FORD      11

# %%
# Numero de presidentes que tienen un nombre menor a una longitud de 12 caracteres
(Presidentes.president.str.len() < 12).sum()
# Out:
# 3

# %%
Presidentes[Presidentes.prior.str.contains(r"\(.*\)", regex=True, na=False)]["prior"]
# Out:
# 0     Commander-in-Chief  of the  Continental Army  ...
# 3     5th  United States Secretary of State   (1801–...
# 4     7th  United States Secretary of State   (1811–...
# 5     8th  United States Secretary of State   (1817–...
# 6     U.S. Senator   ( Class 2 )   from  Tennessee  ...
# 8      United States Minister to Colombia   (1828–1829)
# 10             9th  Governor of Tennessee   (1839–1841)
# 11    Major General  of the  1st Infantry Regiment  ...
# 13    Brigadier General  of the  9th Infantry   Unit...
# 14    United States Minister  to the   Court of St J...
# 15    U.S. Representative  for  Illinois' 7th Distri...
# 17    Commanding General  of the U.S. Army   ( 1864–...
# 18    29th & 32nd  Governor of Ohio   (1868–1872 & 1...
# 19    U.S. Representative  for  Ohio's 19th District...
# 21             28th  Governor of New York   (1883–1885)
# 22    U.S. Senator   ( Class 1 )   from  Indiana   (...
# 23    22nd  President of the United States   (1885–1...
# ...

# %%
Presidentes.president.str.split(n=1)
# Out:
# 0          [George, Washington]
# 1                 [John, Adams]
# 2           [Thomas, Jefferson]
# 3              [James, Madison]
# 4               [James, Monroe]
# 5          [John, Quincy Adams]
# 6             [Andrew, Jackson]
# 7           [Martin, Van Buren]
# 8     [William, Henry Harrison]
# 9                 [John, Tyler]
# 10             [James, K. Polk]
# 11            [Zachary, Taylor]
# 12          [Millard, Fillmore]
# 13           [Franklin, Pierce]
# 14            [James, Buchanan]
# 15           [Abraham, Lincoln]
# 16            [Andrew, Johnson]
# 17          [Ulysses, S. Grant]
# 18       [Rutherford, B. Hayes]
# 19         [James, A. Garfield]
# 20         [Chester, A. Arthur]
# 21          [Grover, Cleveland]
# 22         [Benjamin, Harrison]
# 23          [Grover, Cleveland]
# 24          [William, McKinley]
# 25        [Theodore, Roosevelt]
# 26       [William, Howard Taft]
# 27            [Woodrow, Wilson]
# 28         [Warren, G. Harding]
# ...

# %%
test = Presidentes.president.str.split(n=1, expand=True)[[0, 1]]
Presidentes["First Name"] = test[0]
Presidentes["Last Name"] = test[1]
Presidentes
# Out:
#     Unnamed: 0  S.No.               start                 end  \
# 0            0      1      April 30, 1789       March 4, 1797
# 1            1      2       March 4, 1797       March 4, 1801
# 2            2      3       March 4, 1801       March 4, 1809
# 3            3      4       March 4, 1809       March 4, 1817
# 4            4      5       March 4, 1817       March 4, 1825
# 5            5      6       March 4, 1825       March 4, 1829
# 6            6      7       March 4, 1829       March 4, 1837
# 7            7      8       March 4, 1837       March 4, 1841
# 8            8      9       March 4, 1841       April 4, 1841
# 9            9     10       April 4, 1841       March 4, 1845
# 10          10     11       March 4, 1845       March 4, 1849
# 11          11     12       March 4, 1849        July 9, 1850
# 12          12     13        July 9, 1850       March 4, 1853
# 13          13     14       March 4, 1853       March 4, 1857
# ...

# %%
# Reemplazar corchetes con informacion '[]' con espacio en blanco.
Presidentes.party.str.replace(r"\[[A-Za-z0-9]+\]", "", regex=True)
# Out:
# 0                                  Nonpartisan
# 1                                      Federalist
# 2                         Democratic-  Republican
# 3                         Democratic-  Republican
# 4                         Democratic-  Republican
# 5                         Democratic-  Republican
# 6                                      Democratic
# 7                                      Democratic
# 8                                            Whig
# 9     Whig   April 4, 1841  –  September 13, 1841
# 10                                     Democratic
# 11                                           Whig
# 12                                           Whig
# 13                                     Democratic
# 14                                     Democratic
# 15             Republican   ( National Union )
# 16          National Union      ( Democratic )
# 17                                     Republican
# 18                                     Republican
# ...
