# %% [markdown]
# # Recolección de datos para Reto TDR

# %%
import pandas as pd

df1 = pd.read_csv("Analisis de Cargas _ 2024 Ultimo trimestre - Cargas.csv") 
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10994 entries, 0 to 10993
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Unidad                10967 non-null  object
#  1   Flota                 10874 non-null  object
#  2   EC                    10874 non-null  object
#  3   Fecha de Transacción  10994 non-null  object
#  4   Operador              10758 non-null  object
#  5   ID OPERADOR           10751 non-null  object
#  6   Estación              10994 non-null  object
#  7   Costo por litro       10994 non-null  object
#  8   Litros                10994 non-null  int64
#  9   Costo por carga       10991 non-null  object
#  10  Tipo de Carga         10994 non-null  object
#  11  Semana                10994 non-null  int64
#  12  Día                   10994 non-null  int64
#  13  Mes                   10994 non-null  int64
#  14  Producto              10994 non-null  object
# ...

# %%
df1
# Out:
#       Unidad              Flota     EC Fecha de Transacción  \
# 0       1892         Full Liver  EC-01            2/10/2024
# 1       1683      Pilgrims Tepo  EC-02            2/10/2024
# 2       1975     Sayer Sencillo  EC-04            2/10/2024
# 3       1854          Circuitos  EC-03            2/10/2024
# 4       1935  Patieros sucursal  EC-03            2/10/2024
# ...      ...                ...    ...                  ...
# 10989   1827         Full Liver  EC-01           31/12/2024
# 10990   1943          Circuitos  EC-03           31/12/2024
# 10991   1912   MeLi asignado SD  EC-05           31/12/2024
# 10992   1920   MeLi asignado SD  EC-05           31/12/2024
# 10993   1928    MeLi Ded Puebla  EC-05           31/12/2024
#
#                                 Operador ID OPERADOR     Estación  \
# 0                 CALDERON TEJEDA VICTOR       CALVI        ATBMX
# 1        HERNANDEZ MARTINEZ JUAN DE DIOS    HERJUA01        ATBMX
# ...

# %%
df2 = pd.read_csv("Analisis de Cargas al 7 de Marzo 2025 - Cargas.csv")
df2.head()
# Out:
#   Unidad            Flota     EC Fecha de Transacción  \
# 0   2060         PISA Gdl  EC-06             1/1/2025
# 1   1870        Circuitos  EC-03             1/1/2025
# 2   1839  Liverpool Local  EC-01             1/1/2025
# 3   1821        Circuitos  EC-03             1/1/2025
# 4   1897       Full Liver  EC-01             1/1/2025
#
#                           Operador ID OPERADOR Estación Costo por litro  \
# 0         VALENCIA CARILLO GUSTAVO      VALGUS    ATBMX          $19.17
# 1              RIOS ORTIZ FERNANDO       RIOFE    ATBMX          $19.17
# 2        PERCINO ALCANTARA ANTONIO      PERANT    ATBMX          $19.17
# 3              BAUTISTA LOPEZ LUIS      BAULUI    ATBMX          $19.17
# 4  RODRIGUEZ MORALES ARMANDO EDGAR       RODAR    ATBMX          $19.17
#
#    Litros Costo por carga Tipo de Carga  Semana  Día  Mes Producto
# 0     380       $7,284.60    Autoabasto       1    1    1   Diesel
# 1     500       $9,585.00    Autoabasto       1    1    1   Diesel
# ...

# %%
df_C = pd.concat([df1, df2])
df_C.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 17975 entries, 0 to 6980
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Unidad                17940 non-null  object
#  1   Flota                 17757 non-null  object
#  2   EC                    17753 non-null  object
#  3   Fecha de Transacción  17975 non-null  object
#  4   Operador              17675 non-null  object
#  5   ID OPERADOR           17659 non-null  object
#  6   Estación              17975 non-null  object
#  7   Costo por litro       17975 non-null  object
#  8   Litros                17975 non-null  int64
#  9   Costo por carga       17972 non-null  object
#  10  Tipo de Carga         17975 non-null  object
#  11  Semana                17975 non-null  int64
#  12  Día                   17975 non-null  int64
#  13  Mes                   17975 non-null  int64
#  14  Producto              17968 non-null  object
# ...

# %%
df_C.describe().T
# Out:
#           count        mean         std  min    25%    50%    75%     max
# Litros  17975.0  395.331627  201.289937  0.0  250.0  368.0  517.0  1029.0
# Semana  17975.0   30.556106   20.066959  1.0    7.0   42.0   48.0    53.0
# Día     17975.0   15.345535    8.753682  1.0    7.0   15.0   23.0    31.0
# Mes     17975.0    7.363227    4.623270  1.0    2.0   10.0   11.0    12.0
