# %% [markdown]
# # Scroll Ordenes kms total

# %%
import pandas as pd 

df = pd.read_excel("scroll Ordenes kms total.xlsx")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45394 entries, 0 to 45393
# Data columns (total 30 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   ord_number             45394 non-null  int64
#  1   EC                     45394 non-null  object
#  2   ID Proyecto            45394 non-null  object
#  3   Proyecto               45394 non-null  object
#  4   Cliente                45394 non-null  object
#  5   Ub. Cliente            45394 non-null  object
#  6   ID Origen              45394 non-null  object
#  7   Compañia Origen        45394 non-null  object
#  8   Cp Origen              45394 non-null  int64
#  9   Ciudad Origen          45394 non-null  object
#  10  ID Destino             45394 non-null  object
#  11  CP Destino             45394 non-null  object
#  12  Ciudad Destino         45394 non-null  object
#  13  ord_status             45394 non-null  object
# ...

# %%
df.describe(include='all').T
# Out:
#                          count unique                         top    freq  \
# ord_number             45394.0    NaN                         NaN     NaN
# EC                       45394     10                         EC1   18997
# ID Proyecto              45394     41                         HED   18457
# Proyecto                 45394     41                   LIVERPOOL   18457
# Cliente                  45394     60                    LIVERDED   18457
# Ub. Cliente              45394     36     CUAJIMALPA DE MORE,CDMX   21169
# ID Origen                45394    363                    CDTLIVTL   14139
# Compañia Origen          45394    356     BOD LIVERPOOL TULTITLAN   14139
# Cp Origen              45394.0    NaN                         NaN     NaN
# Ciudad Origen            45394    168                TULTITLAN,EM   14655
# ID Destino               45394    674                    CDTLIVTL    7781
# CP Destino             45394.0  448.0                     54940.0  7832.0
# ...

# %%
import missingno as msgno

msgno.matrix(df)
# Out:
# <Axes: >

# %%
df.isnull().sum()
# Out:
# ord_number                 0
# EC                         0
# ID Proyecto                0
# Proyecto                   0
# Cliente                    0
# Ub. Cliente                0
# ID Origen                  0
# Compañia Origen            0
# Cp Origen                  0
# Ciudad Origen              0
# ID Destino                 0
# CP Destino                 0
# Ciudad Destino             0
# ord_status                 0
# ord_status_name            0
# ord_invoicestatus          0
# Inicio de la Orden         0
# Cierre de la Orden         0
# Tracto                     0
# Conductor                  0
# Conductor 2                0
# Remolque 1                 0
# Remolque 2               295
# Ref Cliente              519
# ord_totalcharge            0
# Monto $                    0
# Mercancias                 0
# Kilometros Recorridos      0
# ord_totalmiles             0
# kmstotales                 0
# dtype: int64

# %%
df.boxplot(vert=False)
# Out:
# <Axes: >

# %%
df['ord_number'].describe().T
# Out:
# count    4.539400e+04
# mean     1.471005e+06
# std      2.704720e+04
# min      1.341726e+06
# 25%      1.433470e+06
# 50%      1.480248e+06
# 75%      1.491848e+06
# max      1.504008e+06
# Name: ord_number, dtype: float64

# %%
df['Monto $'].describe().T
# Out:
# count     45394.000000
# mean      12229.448526
# std       23536.175954
# min         -60.860000
# 25%           0.010000
# 50%           0.010000
# 75%       12336.000000
# max      228870.840000
# Name: Monto $, dtype: float64

# %% [markdown]
# ## ¿Porqué hay montos negativos?
